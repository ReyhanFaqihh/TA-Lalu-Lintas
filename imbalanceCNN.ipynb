# %%
import os
import numpy as np
import cv2
from sklearn.cluster import KMeans
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model

# %%
# Path ke dataset
majority_class_path = "D:\\TA_Lalu_Lintas\\TA-Lalu-Lintas\\dataset_cnn\\helmet_worn"  # Folder kelas mayoritas
output_path = "D:\\TA_Lalu_Lintas\\TA-Lalu-Lintas\\dataset_cnn\\helmet_worn_undersampling1"  # Folder hasil undersampling

# Load ResNet50 untuk ekstraksi fitur (bisa ganti dengan model lain)
base_model = ResNet50(weights="imagenet", include_top=False, pooling="avg")
model = Model(inputs=base_model.input, outputs=base_model.output)

# Fungsi untuk membaca dan mengekstrak fitur dari gambar
def extract_features(image_path, model):
    img = cv2.imread(image_path)

    if img is None:
        raise ValueError(f"❌ Gagal membaca gambar: {image_path}. Periksa path atau format file.")

    img = img.astype(np.float32) 
    img = cv2.resize(img, (224, 224))  # Sesuaikan ukuran dengan model
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)  # Normalisasi untuk model
    features = model.predict(img)
    return features.flatten()

# Load semua gambar kelas mayoritas
image_paths = [os.path.join(majority_class_path, f) for f in os.listdir(majority_class_path) if f.endswith((".jpg", ".png"))]

# Ekstrak fitur dari setiap gambar
feature_list = []
for img_path in image_paths:
    feature = extract_features(img_path, model)
    feature_list.append(feature)

# Ubah ke array numpy
features = np.array(feature_list)

# Tentukan jumlah cluster (misalnya, samakan dengan jumlah data kelas minoritas)
num_clusters = 745  # Sesuaikan dengan jumlah data kelas minoritas

# Jalankan K-Means Clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
kmeans.fit(features)

# Pilih satu gambar dari setiap cluster sebagai sampel representatif
selected_images = []
for cluster_id in range(num_clusters):
    indices = np.where(kmeans.labels_ == cluster_id)[0]
    selected_images.append(image_paths[indices[0]])  # Ambil gambar pertama di cluster

# Simpan hasil undersampling
if not os.path.exists(output_path):
    os.makedirs(output_path)

for img_path in selected_images:
    img_name = os.path.basename(img_path)
    new_path = os.path.join(output_path, img_name)
    os.rename(img_path, new_path)  # Pindahkan gambar

print(f"✅ Undersampling selesai! Dataset mayoritas dikurangi menjadi {len(selected_images)} gambar.")
# Out:
# d:\ComputerVision\belajarConda\envs\python-cvcourse\lib\site-packages\sklearn\metrics\pairwise.py:257: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# ✅ Undersampling selesai! Dataset mayoritas dikurangi menjadi 745 gambar.

# %%
import os

def rename_images(folder_path, prefix="image"):
    # Pastikan folder ada
    if not os.path.exists(folder_path):
        print("Folder tidak ditemukan!")
        return
    
    # Ambil daftar file dalam folder dan urutkan
    files = sorted(os.listdir(folder_path))
    
    # Filter hanya file gambar (jpg, png, jpeg)
    image_files = [f for f in files if f.lower().endswith(('jpg', 'png', 'jpeg'))]
    
    for index, filename in enumerate(image_files, start=1):
        ext = filename.split('.')[-1]  # Ambil ekstensi file
        new_name = f"{prefix}_{index:03d}.{ext}"  # Format nama baru
        old_path = os.path.join(folder_path, filename)
        new_path = os.path.join(folder_path, new_name)
        
        os.rename(old_path, new_path)
        print(f"{filename} -> {new_name}")

# Contoh penggunaan
folder_dataset = "D:\\TA_Lalu_Lintas\\TA-Lalu-Lintas\\dataset_cnn\\Tidak-Memakai-Helm"  # Ganti dengan path folder dataset Anda
rename_images(folder_dataset)
# Out:
# head_0001.jpg -> image_001.jpg
# head_0002.jpg -> image_002.jpg
# head_0003.jpg -> image_003.jpg
# head_0004.jpg -> image_004.jpg
# head_0005.jpg -> image_005.jpg
# head_0006.jpg -> image_006.jpg
# head_0007.jpg -> image_007.jpg
# head_0008.jpg -> image_008.jpg
# head_0009.jpg -> image_009.jpg
# head_0010.jpg -> image_010.jpg
# head_0011.jpg -> image_011.jpg
# head_0012.jpg -> image_012.jpg
# head_0013.jpg -> image_013.jpg
# head_0014.jpg -> image_014.jpg
# head_0015.jpg -> image_015.jpg
# head_0016.jpg -> image_016.jpg
# head_0017.jpg -> image_017.jpg
# head_0018.jpg -> image_018.jpg
# head_0019.jpg -> image_019.jpg
# head_0020.jpg -> image_020.jpg
# head_0021.jpg -> image_021.jpg
# head_0022.jpg -> image_022.jpg
# head_0023.jpg -> image_023.jpg
# head_0024.jpg -> image_024.jpg
# head_0025.jpg -> image_025.jpg
# head_0026.jpg -> image_026.jpg
# head_0027.jpg -> image_027.jpg
# head_0028.jpg -> image_028.jpg
# head_0029.jpg -> image_029.jpg
# head_0030.jpg -> image_030.jpg
# head_0031.jpg -> image_031.jpg
# head_0032.jpg -> image_032.jpg
# head_0033.jpg -> image_033.jpg
# head_0034.jpg -> image_034.jpg
# head_0035.jpg -> image_035.jpg
# head_0036.jpg -> image_036.jpg
# head_0037.jpg -> image_037.jpg
# head_0038.jpg -> image_038.jpg
# head_0039.jpg -> image_039.jpg
# head_0040.jpg -> image_040.jpg
# head_0041.jpg -> image_041.jpg
# head_0042.jpg -> image_042.jpg
# head_0043.jpg -> image_043.jpg
# head_0044.jpg -> image_044.jpg
# head_0045.jpg -> image_045.jpg
# head_0046.jpg -> image_046.jpg
# head_0047.jpg -> image_047.jpg
# head_0048.jpg -> image_048.jpg
# head_0049.jpg -> image_049.jpg
# head_0050.jpg -> image_050.jpg
# head_0051.jpg -> image_051.jpg
# head_0052.jpg -> image_052.jpg
# head_0053.jpg -> image_053.jpg
# head_0054.jpg -> image_054.jpg
# head_0055.jpg -> image_055.jpg
# head_0056.jpg -> image_056.jpg
# head_0057.jpg -> image_057.jpg
# head_0058.jpg -> image_058.jpg
# head_0059.jpg -> image_059.jpg
# head_0060.jpg -> image_060.jpg
# head_0061.jpg -> image_061.jpg
# head_0062.jpg -> image_062.jpg
# head_0063.jpg -> image_063.jpg
# head_0064.jpg -> image_064.jpg
# head_0065.jpg -> image_065.jpg
# head_0066.jpg -> image_066.jpg
# head_0067.jpg -> image_067.jpg
# head_0068.jpg -> image_068.jpg
# head_0069.jpg -> image_069.jpg
# head_0070.jpg -> image_070.jpg
# head_0071.jpg -> image_071.jpg
# head_0072.jpg -> image_072.jpg
# head_0073.jpg -> image_073.jpg
# head_0074.jpg -> image_074.jpg
# head_0075.jpg -> image_075.jpg
# head_0076.jpg -> image_076.jpg
# head_0077.jpg -> image_077.jpg
# head_0078.jpg -> image_078.jpg
# head_0079.jpg -> image_079.jpg
# head_0080.jpg -> image_080.jpg
# head_0081.jpg -> image_081.jpg
# head_0082.jpg -> image_082.jpg
# head_0083.jpg -> image_083.jpg
# head_0084.jpg -> image_084.jpg
# head_0085.jpg -> image_085.jpg
# head_0086.jpg -> image_086.jpg
# head_0087.jpg -> image_087.jpg
# head_0088.jpg -> image_088.jpg
# head_0089.jpg -> image_089.jpg
# head_0090.jpg -> image_090.jpg
# head_0091.jpg -> image_091.jpg
# head_0092.jpg -> image_092.jpg
# head_0093.jpg -> image_093.jpg
# head_0094.jpg -> image_094.jpg
# head_0095.jpg -> image_095.jpg
# head_0096.jpg -> image_096.jpg
# head_0097.jpg -> image_097.jpg
# head_0098.jpg -> image_098.jpg
# head_0099.jpg -> image_099.jpg
# head_0100.jpg -> image_100.jpg
# head_0101.jpg -> image_101.jpg
# head_0102.jpg -> image_102.jpg
# head_0103.jpg -> image_103.jpg
# head_0104.jpg -> image_104.jpg
# head_0105.jpg -> image_105.jpg
# head_0106.jpg -> image_106.jpg
# head_0107.jpg -> image_107.jpg
# head_0108.jpg -> image_108.jpg
# head_0109.jpg -> image_109.jpg
# head_0110.jpg -> image_110.jpg
# head_0111.jpg -> image_111.jpg
# head_0112.jpg -> image_112.jpg
# head_0113.jpg -> image_113.jpg
# head_0114.jpg -> image_114.jpg
# head_0115.jpg -> image_115.jpg
# head_0116.jpg -> image_116.jpg
# head_0117.jpg -> image_117.jpg
# head_0118.jpg -> image_118.jpg
# head_0119.jpg -> image_119.jpg
# head_0120.jpg -> image_120.jpg
# head_0121.jpg -> image_121.jpg
# head_0122.jpg -> image_122.jpg
# head_0123.jpg -> image_123.jpg
# head_0124.jpg -> image_124.jpg
# head_0125.jpg -> image_125.jpg
# head_0126.jpg -> image_126.jpg
# head_0127.jpg -> image_127.jpg
# head_0128.jpg -> image_128.jpg
# head_0129.jpg -> image_129.jpg
# head_0130.jpg -> image_130.jpg
# head_0131.jpg -> image_131.jpg
# head_0132.jpg -> image_132.jpg
# head_0133.jpg -> image_133.jpg
# head_0134.jpg -> image_134.jpg
# head_0135.jpg -> image_135.jpg
# head_0136.jpg -> image_136.jpg
# head_0137.jpg -> image_137.jpg
# head_0138.jpg -> image_138.jpg
# head_0139.jpg -> image_139.jpg
# head_0140.jpg -> image_140.jpg
# head_0141.jpg -> image_141.jpg
# head_0142.jpg -> image_142.jpg
# head_0143.jpg -> image_143.jpg
# head_0144.jpg -> image_144.jpg
# head_0145.jpg -> image_145.jpg
# head_0146.jpg -> image_146.jpg
# head_0147.jpg -> image_147.jpg
# head_0148.jpg -> image_148.jpg
# head_0149.jpg -> image_149.jpg
# head_0150.jpg -> image_150.jpg
# head_0151.jpg -> image_151.jpg
# head_0152.jpg -> image_152.jpg
# head_0153.jpg -> image_153.jpg
# head_0154.jpg -> image_154.jpg
# head_0155.jpg -> image_155.jpg
# head_0156.jpg -> image_156.jpg
# head_0157.jpg -> image_157.jpg
# head_0158.jpg -> image_158.jpg
# head_0159.jpg -> image_159.jpg
# head_0160.jpg -> image_160.jpg
# head_0161.jpg -> image_161.jpg
# head_0162.jpg -> image_162.jpg
# head_0163.jpg -> image_163.jpg
# head_0164.jpg -> image_164.jpg
# head_0165.jpg -> image_165.jpg
# head_0166.jpg -> image_166.jpg
# head_0167.jpg -> image_167.jpg
# head_0168.jpg -> image_168.jpg
# head_0169.jpg -> image_169.jpg
# head_0170.jpg -> image_170.jpg
# head_0171.jpg -> image_171.jpg
# head_0172.jpg -> image_172.jpg
# head_0173.jpg -> image_173.jpg
# head_0174.jpg -> image_174.jpg
# head_0175.jpg -> image_175.jpg
# head_0176.jpg -> image_176.jpg
# head_0177.jpg -> image_177.jpg
# head_0178.jpg -> image_178.jpg
# head_0179.jpg -> image_179.jpg
# head_0180.jpg -> image_180.jpg
# head_0181.jpg -> image_181.jpg
# head_0182.jpg -> image_182.jpg
# head_0183.jpg -> image_183.jpg
# head_0184.jpg -> image_184.jpg
# head_0185.jpg -> image_185.jpg
# head_0186.jpg -> image_186.jpg
# head_0187.jpg -> image_187.jpg
# head_0188.jpg -> image_188.jpg
# head_0189.jpg -> image_189.jpg
# head_0190.jpg -> image_190.jpg
# head_0191.jpg -> image_191.jpg
# head_0192.jpg -> image_192.jpg
# head_0193.jpg -> image_193.jpg
# head_0194.jpg -> image_194.jpg
# head_0195.jpg -> image_195.jpg
# head_0196.jpg -> image_196.jpg
# head_0197.jpg -> image_197.jpg
# head_0198.jpg -> image_198.jpg
# head_0199.jpg -> image_199.jpg
# head_0200.jpg -> image_200.jpg
# head_0201.jpg -> image_201.jpg
# head_0202.jpg -> image_202.jpg
# head_0203.jpg -> image_203.jpg
# head_0204.jpg -> image_204.jpg
# head_0205.jpg -> image_205.jpg
# head_0206.jpg -> image_206.jpg
# head_0207.jpg -> image_207.jpg
# head_0208.jpg -> image_208.jpg
# head_0209.jpg -> image_209.jpg
# head_0210.jpg -> image_210.jpg
# head_0211.jpg -> image_211.jpg
# head_0212.jpg -> image_212.jpg
# head_0213.jpg -> image_213.jpg
# head_0214.jpg -> image_214.jpg
# head_0215.jpg -> image_215.jpg
# head_0216.jpg -> image_216.jpg
# head_0217.jpg -> image_217.jpg
# head_0218.jpg -> image_218.jpg
# head_0219.jpg -> image_219.jpg
# head_0220.jpg -> image_220.jpg
# head_0222.jpg -> image_221.jpg
# head_0223.jpg -> image_222.jpg
# head_0224.jpg -> image_223.jpg
# head_0225.jpg -> image_224.jpg
# head_0226.jpg -> image_225.jpg
# head_0227.jpg -> image_226.jpg
# head_0228.jpg -> image_227.jpg
# head_0229.jpg -> image_228.jpg
# head_0230.jpg -> image_229.jpg
# head_0231.jpg -> image_230.jpg
# head_0232.jpg -> image_231.jpg
# head_0233.jpg -> image_232.jpg
# head_0234.jpg -> image_233.jpg
# head_0235.jpg -> image_234.jpg
# head_0236.jpg -> image_235.jpg
# head_0237.jpg -> image_236.jpg
# head_0238.jpg -> image_237.jpg
# head_0239.jpg -> image_238.jpg
# head_0240.jpg -> image_239.jpg
# head_0241.jpg -> image_240.jpg
# head_0242.jpg -> image_241.jpg
# head_0243.jpg -> image_242.jpg
# head_0244.jpg -> image_243.jpg
# head_0245.jpg -> image_244.jpg
# head_0246.jpg -> image_245.jpg
# head_0247.jpg -> image_246.jpg
# head_0248.jpg -> image_247.jpg
# head_0249.jpg -> image_248.jpg
# head_0250.jpg -> image_249.jpg
# head_0252.jpg -> image_250.jpg
# head_0253.jpg -> image_251.jpg
# head_0254.jpg -> image_252.jpg
# head_0255.jpg -> image_253.jpg
# head_0256.jpg -> image_254.jpg
# head_0257.jpg -> image_255.jpg
# head_0258.jpg -> image_256.jpg
# head_0259.jpg -> image_257.jpg
# head_0260.jpg -> image_258.jpg
# head_0261.jpg -> image_259.jpg
# head_0262.jpg -> image_260.jpg
# head_0263.jpg -> image_261.jpg
# head_0264.jpg -> image_262.jpg
# head_0265.jpg -> image_263.jpg
# head_0266.jpg -> image_264.jpg
# head_0267.jpg -> image_265.jpg
# head_0268.jpg -> image_266.jpg
# head_0269.jpg -> image_267.jpg
# head_0270.jpg -> image_268.jpg
# head_0271.jpg -> image_269.jpg
# head_0272.jpg -> image_270.jpg
# head_0273.jpg -> image_271.jpg
# head_0274.jpg -> image_272.jpg
# head_0275.jpg -> image_273.jpg
# head_0276.jpg -> image_274.jpg
# head_0277.jpg -> image_275.jpg
# head_0278.jpg -> image_276.jpg
# head_0279.jpg -> image_277.jpg
# head_0280.jpg -> image_278.jpg
# head_0281.jpg -> image_279.jpg
# head_0282.jpg -> image_280.jpg
# head_0283.jpg -> image_281.jpg
# head_0284.jpg -> image_282.jpg
# head_0285.jpg -> image_283.jpg
# head_0286.jpg -> image_284.jpg
# head_0287.jpg -> image_285.jpg
# head_0288.jpg -> image_286.jpg
# head_0289.jpg -> image_287.jpg
# head_0290.jpg -> image_288.jpg
# head_0291.jpg -> image_289.jpg
# head_0292.jpg -> image_290.jpg
# head_0293.jpg -> image_291.jpg
# head_0294.jpg -> image_292.jpg
# head_0295.jpg -> image_293.jpg
# head_0296.jpg -> image_294.jpg
# head_0297.jpg -> image_295.jpg
# head_0298.jpg -> image_296.jpg
# head_0299.jpg -> image_297.jpg
# head_0300.jpg -> image_298.jpg
# head_0301.jpg -> image_299.jpg
# head_0302.jpg -> image_300.jpg
# head_0303.jpg -> image_301.jpg
# head_0304.jpg -> image_302.jpg
# head_0305.jpg -> image_303.jpg
# head_0306.jpg -> image_304.jpg
# head_0307.jpg -> image_305.jpg
# head_0308.jpg -> image_306.jpg
# head_0309.jpg -> image_307.jpg
# head_0311.jpg -> image_308.jpg
# head_0312.jpg -> image_309.jpg
# head_0313.jpg -> image_310.jpg
# head_0314.jpg -> image_311.jpg
# head_0315.jpg -> image_312.jpg
# head_0316.jpg -> image_313.jpg
# head_0317.jpg -> image_314.jpg
# head_0318.jpg -> image_315.jpg
# head_0319.jpg -> image_316.jpg
# head_0320.jpg -> image_317.jpg
# head_0322.jpg -> image_318.jpg
# head_0323.jpg -> image_319.jpg
# head_0324.jpg -> image_320.jpg
# head_0325.jpg -> image_321.jpg
# head_0326.jpg -> image_322.jpg
# head_0327.jpg -> image_323.jpg
# head_0328.jpg -> image_324.jpg
# head_0329.jpg -> image_325.jpg
# head_0330.jpg -> image_326.jpg
# head_0331.jpg -> image_327.jpg
# head_0333.jpg -> image_328.jpg
# head_0334.jpg -> image_329.jpg
# head_0335.jpg -> image_330.jpg
# head_0336.jpg -> image_331.jpg
# head_0337.jpg -> image_332.jpg
# head_0338.jpg -> image_333.jpg
# head_0339.jpg -> image_334.jpg
# head_0340.jpg -> image_335.jpg
# head_0341.jpg -> image_336.jpg
# head_0342.jpg -> image_337.jpg
# head_0343.jpg -> image_338.jpg
# head_0344.jpg -> image_339.jpg
# head_0345.jpg -> image_340.jpg
# head_0346.jpg -> image_341.jpg
# head_0347.jpg -> image_342.jpg
# head_0348.jpg -> image_343.jpg
# head_0349.jpg -> image_344.jpg
# head_0350.jpg -> image_345.jpg
# head_0351.jpg -> image_346.jpg
# head_0352.jpg -> image_347.jpg
# head_0353.jpg -> image_348.jpg
# head_0354.jpg -> image_349.jpg
# head_0355.jpg -> image_350.jpg
# head_0356.jpg -> image_351.jpg
# head_0357.jpg -> image_352.jpg
# head_0358.jpg -> image_353.jpg
# head_0359.jpg -> image_354.jpg
# head_0360.jpg -> image_355.jpg
# head_0361.jpg -> image_356.jpg
# head_0362.jpg -> image_357.jpg
# head_0363.jpg -> image_358.jpg
# head_0364.jpg -> image_359.jpg
# head_0365.jpg -> image_360.jpg
# head_0366.jpg -> image_361.jpg
# head_0367.jpg -> image_362.jpg
# head_0368.jpg -> image_363.jpg
# head_0369.jpg -> image_364.jpg
# head_0370.jpg -> image_365.jpg
# head_0371.jpg -> image_366.jpg
# head_0372.jpg -> image_367.jpg
# head_0373.jpg -> image_368.jpg
# head_0374.jpg -> image_369.jpg
# head_0375.jpg -> image_370.jpg
# head_0376.jpg -> image_371.jpg
# head_0377.jpg -> image_372.jpg
# head_0378.jpg -> image_373.jpg
# head_0379.jpg -> image_374.jpg
# head_0380.jpg -> image_375.jpg
# head_0381.jpg -> image_376.jpg
# head_0382.jpg -> image_377.jpg
# head_0383.jpg -> image_378.jpg
# head_0384.jpg -> image_379.jpg
# head_0385.jpg -> image_380.jpg
# head_0386.jpg -> image_381.jpg
# head_0387.jpg -> image_382.jpg
# head_0388.jpg -> image_383.jpg
# head_0389.jpg -> image_384.jpg
# head_0390.jpg -> image_385.jpg
# head_0391.jpg -> image_386.jpg
# head_0392.jpg -> image_387.jpg
# head_0393.jpg -> image_388.jpg
# head_0394.jpg -> image_389.jpg
# head_0395.jpg -> image_390.jpg
# head_0396.jpg -> image_391.jpg
# head_0397.jpg -> image_392.jpg
# head_0398.jpg -> image_393.jpg
# head_0399.jpg -> image_394.jpg
# head_0400.jpg -> image_395.jpg
# head_0401.jpg -> image_396.jpg
# head_0402.jpg -> image_397.jpg
# head_0403.jpg -> image_398.jpg
# head_0404.jpg -> image_399.jpg
# head_0405.jpg -> image_400.jpg
# head_0406.jpg -> image_401.jpg
# head_0407.jpg -> image_402.jpg
# head_0408.jpg -> image_403.jpg
# head_0409.jpg -> image_404.jpg
# head_0410.jpg -> image_405.jpg
# head_0411.jpg -> image_406.jpg
# head_0414.jpg -> image_407.jpg
# head_0417.jpg -> image_408.jpg
# head_0418.jpg -> image_409.jpg
# head_0419.jpg -> image_410.jpg
# head_0420.jpg -> image_411.jpg
# head_0421.jpg -> image_412.jpg
# head_0422.jpg -> image_413.jpg
# head_0423.jpg -> image_414.jpg
# head_0424.jpg -> image_415.jpg
# head_0425.jpg -> image_416.jpg
# head_0426.jpg -> image_417.jpg
# head_0427.jpg -> image_418.jpg
# head_0428.jpg -> image_419.jpg
# head_0429.jpg -> image_420.jpg
# head_0430.jpg -> image_421.jpg
# head_0431.jpg -> image_422.jpg
# head_0432.jpg -> image_423.jpg
# head_0433.jpg -> image_424.jpg
# head_0434.jpg -> image_425.jpg
# head_0435.jpg -> image_426.jpg
# head_0436.jpg -> image_427.jpg
# head_0437.jpg -> image_428.jpg
# head_0438.jpg -> image_429.jpg
# head_0440.jpg -> image_430.jpg
# head_0443.jpg -> image_431.jpg
# head_0444.jpg -> image_432.jpg
# head_0445.jpg -> image_433.jpg
# head_0446.jpg -> image_434.jpg
# head_0447.jpg -> image_435.jpg
# head_0448.jpg -> image_436.jpg
# head_0449.jpg -> image_437.jpg
# head_0451.jpg -> image_438.jpg
# head_0452.jpg -> image_439.jpg
# head_0453.jpg -> image_440.jpg
# head_0454.jpg -> image_441.jpg
# head_0456.jpg -> image_442.jpg
# head_0457.jpg -> image_443.jpg
# head_0458.jpg -> image_444.jpg
# head_0459.jpg -> image_445.jpg
# head_0460.jpg -> image_446.jpg
# head_0462.jpg -> image_447.jpg
# head_0465.jpg -> image_448.jpg
# head_0466.jpg -> image_449.jpg
# head_0467.jpg -> image_450.jpg
# head_0468.jpg -> image_451.jpg
# head_0469.jpg -> image_452.jpg
# head_0470.jpg -> image_453.jpg
# head_0471.jpg -> image_454.jpg
# head_0472.jpg -> image_455.jpg
# head_0473.jpg -> image_456.jpg
# head_0474.jpg -> image_457.jpg
# head_0478.jpg -> image_458.jpg
# head_0479.jpg -> image_459.jpg
# head_0480.jpg -> image_460.jpg
# head_0482.jpg -> image_461.jpg
# head_0483.jpg -> image_462.jpg
# head_0485.jpg -> image_463.jpg
# head_0487.jpg -> image_464.jpg
# head_0488.jpg -> image_465.jpg
# head_0489.jpg -> image_466.jpg
# head_0490.jpg -> image_467.jpg
# head_0492.jpg -> image_468.jpg
# head_0493.jpg -> image_469.jpg
# head_0494.jpg -> image_470.jpg
# head_0496.jpg -> image_471.jpg
# head_0499.jpg -> image_472.jpg
# head_0500.jpg -> image_473.jpg
# head_0501.jpg -> image_474.jpg
# head_0502.jpg -> image_475.jpg
# head_0503.jpg -> image_476.jpg
# head_0504.jpg -> image_477.jpg
# head_0505.jpg -> image_478.jpg
# head_0506.jpg -> image_479.jpg
# head_0508.jpg -> image_480.jpg
# head_0511.jpg -> image_481.jpg
# head_0512.jpg -> image_482.jpg
# head_0513.jpg -> image_483.jpg
# head_0514.jpg -> image_484.jpg
# head_0515.jpg -> image_485.jpg
# head_0517.jpg -> image_486.jpg
# head_0518.jpg -> image_487.jpg
# head_0519.jpg -> image_488.jpg
# head_0520.jpg -> image_489.jpg
# head_0522.jpg -> image_490.jpg
# head_0523.jpg -> image_491.jpg
# head_0524.jpg -> image_492.jpg
# head_0525.jpg -> image_493.jpg
# head_0526.jpg -> image_494.jpg
# head_0527.jpg -> image_495.jpg
# head_0528.jpg -> image_496.jpg
# head_0529.jpg -> image_497.jpg
# head_0530.jpg -> image_498.jpg
# head_0533.jpg -> image_499.jpg
# head_0534.jpg -> image_500.jpg
# head_0535.jpg -> image_501.jpg
# head_0540.jpg -> image_502.jpg
# head_0541.jpg -> image_503.jpg
# head_0544.jpg -> image_504.jpg
# head_0545.jpg -> image_505.jpg
# head_0547.jpg -> image_506.jpg
# head_0550.jpg -> image_507.jpg
# head_0554.jpg -> image_508.jpg
# head_0555.jpg -> image_509.jpg
# head_0556.jpg -> image_510.jpg
# head_0557.jpg -> image_511.jpg
# head_0558.jpg -> image_512.jpg
# head_0559.jpg -> image_513.jpg
# head_0561.jpg -> image_514.jpg
# head_0562.jpg -> image_515.jpg
# head_0563.jpg -> image_516.jpg
# head_0567.jpg -> image_517.jpg
# head_0570.jpg -> image_518.jpg
# head_0571.jpg -> image_519.jpg
# head_0572.jpg -> image_520.jpg
# head_0576.jpg -> image_521.jpg
# head_0577.jpg -> image_522.jpg
# head_0580.jpg -> image_523.jpg
# head_0583.jpg -> image_524.jpg
# head_0586.jpg -> image_525.jpg
# head_0587.jpg -> image_526.jpg
# head_0590.jpg -> image_527.jpg
# head_0592.jpg -> image_528.jpg
# head_0595.jpg -> image_529.jpg
# head_0596.jpg -> image_530.jpg
# head_0597.jpg -> image_531.jpg
# head_0598.jpg -> image_532.jpg
# head_0607.jpg -> image_533.jpg
# head_0608.jpg -> image_534.jpg
# head_0610.jpg -> image_535.jpg
# head_0611.jpg -> image_536.jpg
# head_0613.jpg -> image_537.jpg
# head_0619.jpg -> image_538.jpg
# head_0620.jpg -> image_539.jpg
# head_0621.jpg -> image_540.jpg
# head_0622.jpg -> image_541.jpg
# head_0626.jpg -> image_542.jpg
# head_0630.jpg -> image_543.jpg
# head_0631.jpg -> image_544.jpg
# head_0632.jpg -> image_545.jpg
# head_0634.jpg -> image_546.jpg
# head_0637.jpg -> image_547.jpg
# head_0638.jpg -> image_548.jpg
# head_0639.jpg -> image_549.jpg
# head_0640.jpg -> image_550.jpg
# head_0641.jpg -> image_551.jpg
# head_0644.jpg -> image_552.jpg
# head_0645.jpg -> image_553.jpg
# head_0646.jpg -> image_554.jpg
# head_0649.jpg -> image_555.jpg
# head_0650.jpg -> image_556.jpg
# head_0657.jpg -> image_557.jpg
# head_0662.jpg -> image_558.jpg
# head_0665.jpg -> image_559.jpg
# head_0666.jpg -> image_560.jpg
# head_0667.jpg -> image_561.jpg
# head_0671.jpg -> image_562.jpg
# head_0672.jpg -> image_563.jpg
# head_0673.jpg -> image_564.jpg
# head_0675.jpg -> image_565.jpg
# head_0676.jpg -> image_566.jpg
# head_0677.jpg -> image_567.jpg
# head_0679.jpg -> image_568.jpg
# head_0680.jpg -> image_569.jpg
# head_0681.jpg -> image_570.jpg
# head_0682.jpg -> image_571.jpg
# head_0686.jpg -> image_572.jpg
# head_0689.jpg -> image_573.jpg
# head_0690.jpg -> image_574.jpg
# head_0691.jpg -> image_575.jpg
# head_0692.jpg -> image_576.jpg
# head_0693.jpg -> image_577.jpg
# head_0694.jpg -> image_578.jpg
# head_0695.jpg -> image_579.jpg
# head_0696.jpg -> image_580.jpg
# head_0699.jpg -> image_581.jpg
# head_0701.jpg -> image_582.jpg
# head_0705.jpg -> image_583.jpg
# head_0709.jpg -> image_584.jpg
# head_0715.jpg -> image_585.jpg
# head_0721.jpg -> image_586.jpg
# head_0725.jpg -> image_587.jpg
# head_0726.jpg -> image_588.jpg
# head_0727.jpg -> image_589.jpg
# head_0728.jpg -> image_590.jpg
# head_0729.jpg -> image_591.jpg
# head_0730.jpg -> image_592.jpg
# head_0731.jpg -> image_593.jpg
# head_0734.jpg -> image_594.jpg
# head_0735.jpg -> image_595.jpg
# head_0736.jpg -> image_596.jpg
# head_0737.jpg -> image_597.jpg
# head_0738.jpg -> image_598.jpg
# head_0739.jpg -> image_599.jpg
# head_0741.jpg -> image_600.jpg
# head_0742.jpg -> image_601.jpg
# head_0743.jpg -> image_602.jpg
# head_0746.jpg -> image_603.jpg
# head_0747.jpg -> image_604.jpg
# head_0748.jpg -> image_605.jpg
# head_0749.jpg -> image_606.jpg
# head_0750.jpg -> image_607.jpg
# head_0754.jpg -> image_608.jpg
# head_0755.jpg -> image_609.jpg
# head_0756.jpg -> image_610.jpg
# head_0757.jpg -> image_611.jpg
# head_0758.jpg -> image_612.jpg
# head_0759.jpg -> image_613.jpg
# head_0760.jpg -> image_614.jpg
# head_0771.jpg -> image_615.jpg
# head_0774.jpg -> image_616.jpg
# head_0775.jpg -> image_617.jpg
# head_0776.jpg -> image_618.jpg
# head_0783.jpg -> image_619.jpg
# head_0792.jpg -> image_620.jpg
# head_0798.jpg -> image_621.jpg
# head_0799.jpg -> image_622.jpg
# head_0800.jpg -> image_623.jpg
# head_0803.jpg -> image_624.jpg
# head_0804.jpg -> image_625.jpg
# head_0805.jpg -> image_626.jpg
# head_0806.jpg -> image_627.jpg
# head_0810.jpg -> image_628.jpg
# head_0817.jpg -> image_629.jpg
# head_0818.jpg -> image_630.jpg
# head_0821.jpg -> image_631.jpg
# head_0822.jpg -> image_632.jpg
# head_0823.jpg -> image_633.jpg
# head_0824.jpg -> image_634.jpg
# head_0825.jpg -> image_635.jpg
# head_0826.jpg -> image_636.jpg
# head_0827.jpg -> image_637.jpg
# head_0828.jpg -> image_638.jpg
# head_0832.jpg -> image_639.jpg
# head_0833.jpg -> image_640.jpg
# head_0836.jpg -> image_641.jpg
# head_0837.jpg -> image_642.jpg
# head_0845.jpg -> image_643.jpg
# head_0848.jpg -> image_644.jpg
# head_0849.jpg -> image_645.jpg
# head_0854.jpg -> image_646.jpg
# head_0860.jpg -> image_647.jpg
# head_0861.jpg -> image_648.jpg
# head_0862.jpg -> image_649.jpg
# head_0863.jpg -> image_650.jpg
# head_0864.jpg -> image_651.jpg
# head_0865.jpg -> image_652.jpg
# head_0868.jpg -> image_653.jpg
# head_0869.jpg -> image_654.jpg
# head_0870.jpg -> image_655.jpg
# head_0871.jpg -> image_656.jpg
# head_0872.jpg -> image_657.jpg
# head_0873.jpg -> image_658.jpg
# head_0874.jpg -> image_659.jpg
# head_0875.jpg -> image_660.jpg
# head_0876.jpg -> image_661.jpg
# head_0877.jpg -> image_662.jpg
# head_0878.jpg -> image_663.jpg
# head_0879.jpg -> image_664.jpg
# head_0880.jpg -> image_665.jpg
# head_0886.jpg -> image_666.jpg
# head_0887.jpg -> image_667.jpg
# head_0888.jpg -> image_668.jpg
# head_0890.jpg -> image_669.jpg
# head_0892.jpg -> image_670.jpg
# head_0896.jpg -> image_671.jpg
# head_0897.jpg -> image_672.jpg
# head_0901.jpg -> image_673.jpg
# head_0904.jpg -> image_674.jpg
# head_0905.jpg -> image_675.jpg
# head_0906.jpg -> image_676.jpg
# head_0907.jpg -> image_677.jpg
# head_0909.jpg -> image_678.jpg
# head_0910.jpg -> image_679.jpg
# head_0916.jpg -> image_680.jpg
# head_0917.jpg -> image_681.jpg
# head_0918.jpg -> image_682.jpg
# head_0922.jpg -> image_683.jpg
# head_0923.jpg -> image_684.jpg
# head_0926.jpg -> image_685.jpg
# head_0928.jpg -> image_686.jpg
# head_0932.jpg -> image_687.jpg
# head_0936.jpg -> image_688.jpg
# head_0937.jpg -> image_689.jpg
# head_0938.jpg -> image_690.jpg
# head_0939.jpg -> image_691.jpg
# head_0943.jpg -> image_692.jpg
# head_0946.jpg -> image_693.jpg
# head_0948.jpg -> image_694.jpg
# head_0949.jpg -> image_695.jpg
# head_0951.jpg -> image_696.jpg
# head_0952.jpg -> image_697.jpg
# head_0955.jpg -> image_698.jpg
